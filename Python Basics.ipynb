# %% [markdown]
# ## Basic Calculation in Python

# %% [markdown]
# Python is suited to do basic calculations and perform as a calculator.
#
# ### Addition and Subtraction:
# Similar to a calculator `+` and `-` are the operators that simply perform addition and subtraction respectively.

# %%
print(2+2)
print(4-2)
# Out:
# 4
# 2

# %% [markdown]
# ### Multiplication and Division:
# The operators `*` and `/` perform multiplication and division.

# %%
print(3*10)
print(12/3)
# Out:
# 30
# 4

# %% [markdown]
# ### Exponetiation:
# The `**` raises the number to its left to the power of the number to its right.

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ### Modulo:
# The `%` It returns the remainder of the division of the number to the left by the number on its right.

# %%
print(8%3)
# Out:
# 2

# %% [markdown]
# ## Variables & Data Types

# %% [markdown]
# ### Variable Assignment:

# %% [markdown]
# The equal sign `=` is used to assign a value to a variable.
